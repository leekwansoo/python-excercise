# %% [markdown]
# ## Python Training Package Designed by Kwan Lee
#
# # This training package is internal use to train beginners based on contents of w3schools.org
#
# ---
# **Slide 0: Introduction**
#
# ## Step 0: Download and Install the Vs_Code
#
# from your browser access "https://code.visualstudio.com/download"
#
# ![vscode.png](attachment:vscode.png)
#
# click the Download Button (Largest Top Button for window)
#
# Goto download folder and click the "VSCodeUserSetup-x64-1.104.2.exe"
#
# Install the vs code in the DeskTop(바탕화면)
#
# move mouse to Desktop Vscode icon and click the right side button of your mouse
# then click the "추가옵션보기" => "Code로 열기" in the pop up menu
#
# ![vscode_1.png](attachment:vscode_1.png) ![vscode_2.png](attachment:vscode_2.png)

# %% [markdown]
# ## VSCode 화면 설명

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Preparing the environments for Python Training
#
# ---
# **Slide 1: Environment Setup**
# ![python_org.png](attachment:python_org.png)
# ## Step 1: Download Python Package from Python.org
# - From your browser type "www.python.org"
# - Click the "Downloads" in the menu bar
# - Click the Download Python 3.13.7 button
# - This will download python package into your computer

# %% [markdown]
# # Setting up the jupyter notebook
#
# ## Step 1: create a jupyter notebook file using left top file manager icon
#     test.ipynb  => test.ipynb file will be on the editor area in vscode
#
# you will see the following menu bar at the top of the file
#
# ![ipynb_top_menubar.png](attachment:ipynb_top_menubar.png)
#
# Then click "+ Code" or "+ Markdown" to create a cell

# %% [markdown]
# ## Step 2: Environment Setup
# ## ![select_kernel.png](attachment:select_kernel.png)
# 1. Select Kernel (The button is at the top right corner)
#     click the button: a pop up window will appear at the top center with "Python Environments"
#     click the "Python Environment" : list of options to select "python environment"
#     move the mouse to the python version you want to use (ex: Python 3.xx.x)
