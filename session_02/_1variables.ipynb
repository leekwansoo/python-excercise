# %% [markdown]
# ## Python Training Package Designed by Kwan Lee
#
# # This training package is internal use to train beginners based on contents of w3schools.org
#
# ---
# **Slide 1: Introduction**

# %% [markdown]
# # Preparing the environments for Python Training
#
# ---
# **Slide 2: Environment Setup**
#
# ![python_org.png](attachment:python_org.png)
#
# ## Step 1: Download Python Package from Python.org
# - From your browser type "www.python.org"
# - Click the "Downloads" in the menu bar
# - Click the Download Python 3.13.7 button
# - This will download python package into your computer

# %% [markdown]
# # steps before excercise the jupyter notebook
# ---
# **Slide 3: Environment Setup**
#
#
# 1. Select Kernel (The button is at the top right corner)
#     click the button: a pop up window will appear at the top center with "Python Environments"
#     click the "Python Environment" : list of options to select "python environment"
#     move the mouse to the python version you want to use (ex: Python 3.xx.x)

# %% [markdown]
# ## Operators, Variables, Environments, Utilities
#
# Programming is composed of Operators and Variables
#
# ![programming_process_diagram.jpg](attachment:programming_process_diagram.jpg)

# %%
import sys
import os

print(sys.version)
# Out:
# 3.13.6 (tags/v3.13.6:4e66535, Aug  6 2025, 14:36:00) [MSC v.1944 64 bit (AMD64)]

# %%
print("Hello")
# Out:
# Hello

# %%
a = 1
if a> 2:
    print("a is greater than 2")
else:
    print("a is not greater than 2")
# Out:
# a is not greater than 2

# %%
# This is comment

x = 5  # x is a variable
print(x) # this code prints the value of x
print("x")  # this code prints a string "x"
# Out:
# 5
# x

# %% [markdown]
# ## Creating Variables
#
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.

# %%
# Examples
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
# Casting
# If you want to specify the data type of a variable, this can be done with casting.
x = str(5)
y = int(5)
z = float(5)
total = x + str(z)
print(total)

# %%
# Casting
# If you want to specify the data type of a variable, this can be done with casting.
x = int(5)
y = int(5)
z = float(5)
total = x + y
print(total)
# Out:
# 10

# %%
# Get the type of variables

x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Variable Names
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

# %%
# Examples of variable assignment

myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

_12345 = "John"  # even numbers preceding with "_" is allowed
print(_12345)

# %%
# Examples of variable assignment

myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

_12345 = "John"  # even numbers preceding with "_" is allowed
print(_12345)

_1 = "John"  # even numbers preceding with "_" is allowed
# Out:
# John

# %%
# Illegal variable names

2myvar = "John"
my-var = "John"
my var = "John"
# Out:
#   Cell In[99], line 3
#     2myvar = "John"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Assign Multiple variables
# Python allows you to assign values to multiple variables in one line:

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
# Unpack Collections
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits[0], fruits[1], fruits[2]
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Output Variables
# The Python print() function is often used to output variables.

# %%
x = "Python is awesome" # string variable
print(x)
# Out:
# Python is awesome

# %%
# Concatenate Variables
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5  # x is a variable
y = 10  # y is a variable
print(x + y)  # this code prints the sum of x and y
# Out:
# 15

# %%
x = "5"
y = "10"
print(x + y)
# Out:
# 510

# %%
x = int(5)
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 x = int(5)
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = str(5)
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# # Global Variables
#
# Variables that are created outside of a function (as in all of the examples in the previous pages) are known as global variables.
#
# Global variables can be used by everyone, both inside of functions and outside.

# %%
# Create a variable outside of a function, and use it inside the function

x = "awesome"

def myfunc():
  print("Python is " + x)

# %%
myfunc()
# Out:
# Python is awesome
