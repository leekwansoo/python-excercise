# %% [markdown]
# Notebokk Referneced from Kagggle Exercise

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# Modified setup for local environment (removed Kaggle-specific learntools)
import os
print("Loading libraries for data visualization...")

# Check if data directory exists
if not os.path.exists("data"):
    os.makedirs("data")
    print("Created data directory")

# Note: This notebook is adapted from Kaggle exercises
# Original learntools functionality has been removed for local compatibility
print("Setup Complete - Ready for local data visualization!")
# Out:
# Loading libraries for data visualization...
# Setup Complete - Ready for local data visualization!

# %%
# Load the Data
# Path of the file to read
fifa_filepath = "data/fifa.csv"

# Read the file into a variable fifa_data
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# Check your answer

# %%
# Plot the Data
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)


# Check your an
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Handling IRIS data

# %%
# Load the Data
# Path of the file to read
iris_filepath = "data/iris_data.csv"

# Read the file into a variable iris_data
iris_data = pd.read_csv(iris_filepath)

# Check your answer

# %%
# Plot the Data
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Select only numeric columns for correlation
numeric_iris_data = iris_data.select_dtypes(include=[np.number])
corr_data = numeric_iris_data.corr()

# Create heatmap showing correlation between iris features
sns.heatmap(data=corr_data, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix of Iris Dataset Features")
plt.show()

# Check your answer
