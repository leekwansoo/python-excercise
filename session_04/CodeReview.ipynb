# %% [markdown]
# # Python Learning Review for Week 4

# %% [markdown]
# ### 1. Statements
# Test your understanding of Python statements by completing a small coding challenge.
#
# #### Instructions
# Inside the editor, complete the following steps:
# 1. Write a statement that prints "Hello World!"
# 2. Print the text "I am" and the number 25 in one print statement
# 3. Create a variable x and assign it the value 5
# 4. Use the type() function to print the type of x
# 5. Convert x to a string and store it in y

# %%
# Print "Hello World!"

# Print "I am" and the number 25

# Create variable x with value 5

# Print the type of x

# Convert to string

# %% [markdown]
# ### 2. Strings
# Test your understanding of creating, slicing, modifying, and formatting strings.
#
# #### Instructions
# Inside the editor, complete the following steps:
# 1. Create a variable txt with the value "Hello, World!"
# 2. Print the characters from index 2 to 5 (slicing)
# 3. Print txt converted to upper case
# 4. Create a variable name with the value "Python"
# 5. Use an f-string to print "I love Python" using the name variable

# %%
# Create the variable

# Print characters from index 2 to 5

# Print in upper case

# Create the name variable

# Print using an f-string

# %% [markdown]
# ### 3. Booleans
# Test your understanding of Python booleans by completing a small coding challenge.
#
# #### Instructions
# Inside the editor, complete the following steps:
# 1. Print the result of 10 > 9
# 2. Print the result of 10 == 9
# 3. Print the result of bool("Hello")
# 4. Print the result of bool(0)

# %%
# Print the result of 10 > 9

# Print the result of 10 == 9

# Print the result of bool("Hello")

# Print the result of bool(0)

# %% [markdown]
# ### 4. Operators Basics
# Test your understanding of arithmetic, assignment, and comparison operators.
#
# #### Instructions
# Inside the editor, complete the following steps:
# 1. Create two variables a = 15 and b = 4
# 2. Print the result of a modulus b (the % operator)
# 3. Print the result of a floor division b (the // operator)
# 4. Print the result of a to the power of b (the ** operator)
# 5. Use an assignment operator to add 10 to a (use +=)

# %%
# Create variables

# Print modulus

# Print floor division

# Print power

# Add 10 to and print the result

# %% [markdown]
# ### Challenge 5: Lists, Tuples, Sets Basics
# Test your understanding of creating and checking list, Tuple, Set items.
#
# #### Instructions
# Inside the editor, complete the following steps:
# 1. Create a list called colors with the values "red", "green", "blue"
# 2. Print the list type
# 3. Create a tuple called fruits with the values "apple"
# 4. Print the tuple type
# 5. Create a set called numbers with the values 1, 2, 2, 3
# 6. Print the set

# %%
# Create the List and print its type


# Create the Tuple and print its type


# Create the Set and print it
